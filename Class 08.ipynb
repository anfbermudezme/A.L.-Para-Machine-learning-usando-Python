# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
# %run ".//funciones_auxiliares//graficarvectores.ipynb"
# %run ".//funciones_auxiliares/graficarmatriz.ipynb"

# %%
A = np.array([[3, 7], [5, 2]])
print(A)
# Out:
# [[3 7]
#  [5 2]]

# %%
U, D, V = np.linalg.svd(A)

print(D[0])
print(D[1])

#Para el examen

print(D)
# Out:
# 8.7133796929634
# 3.3282148858288965
# [8.71337969 3.32821489]

# %%
u1 = [D[0]*U[0,0], D[0]*U[0,1]]
v1 = [D[1]*U[1,0], D[1]*U[1,1]]

print([A[0,0], A[1,0]])
print(u1)
print()
print([A[0,1], A[1,1]])
print(v1)
# Out:
# [3, 5]
# [-7.4120434792975685, -4.580894796297923]
#
# [7, 2]
# [-1.7497461132982814, 2.8311486829996433]

# %%
graficarmatriz(A)
graficarvectores([u1, v1], colores=['red', 'blue'])

plt.text(3, 5, r"$u_1$", size = 18)
plt.text(7, 2, r"$v_1$", size = 18)

plt.text(-8, -6, r"$D(u_1)$", size = 18)
plt.text(-3, 3.7, r"$D(v_1)$", size = 18)

plt.xlim(-9, 9)
plt.ylim(-9, 9)
# Out:
# (-9.0, 9.0)
